# %% [markdown]
# # Polytech SI3 - Données numériques
# Diane Lingrand
#
# Diane.Lingrand@univ-cotedazur.fr
#
# 2022-2023
#
# ## Cours 1 - Introduction

# %% [markdown]
# ## 1. Librairies numpy et matplotlib

# %%
#seulement si vous n'avez pas déjà installé ces librairies
# %pip install numpy
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/tsukoyachi/.local/lib/python3.10/site-packages (1.23.5)
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/tsukoyachi/.local/lib/python3.10/site-packages (3.7.0)
# Requirement already satisfied: cycler>=0.10 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: numpy>=1.20 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#chargement des librairies
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.2 tracés de fonctions mathématiques usuelles

# %% [markdown]
# #### exponentielle

# %% [markdown]
# Pour le premier dessin, tracez la courbe qui représente la fonction exponentielle pour les valeurs entières entre 0 et 500.

# %%
# dessin 1
x = np.arange(0,500)
y = np.exp(x)
plt.plot(x,y)

# %% [markdown]
# Peut-on aller vers de plus grandes valeurs? Quelle est la limite? Pourquoi?

# %% [markdown]
# - Réponse : J'arrive à aller jusqu'à exp(710) avant d'avoir une runtimeError à cause d'une erreur d'Overflow.

# %% [markdown]
# Ajoutez des légendes sur les axes de la figure.

# %%
# dessin 1
x = np.arange(0,500)
y = np.exp(x)
plt.xlabel('axe x')
plt.ylabel('axe y')
plt.title('exponentielle de x')
plt.plot(x,y)

# %%
# dessin 2
# tracez la même courbe mais pour des valeurs entières entre 0 et 10
x = np.arange(0,10)
y = np.exp(x)
plt.xlabel('axe x')
plt.ylabel('axe y')
plt.title('exponentielle de x')
plt.plot(x,y)

# %% [markdown]
# Les deux graphiques précédents n'ont pas la même allure. Pourquoi?
# Pour le dessin numéro 2, remplacer les valeurs entières de x par des valeurs décimales de telle sorte qu'il y ait une centaine de valeurs entre 0 et 10.

# %%
x = np.linspace(0,10,100)
y = np.exp(x)
plt.xlabel('axe x')
plt.ylabel('axe y')
plt.title('exponentielle de x')
plt.plot(x,y)

# %% [markdown]
# Pour chaque valeure entière et impaire de x, tracez un petit segment qui passe par ce point (xi,yi) et de pente exp(xi). A quoi cela correspond?

# %%
# Le graphe de l'exp
x = np.linspace(0,10,100)
y = np.exp(x)
plt.xlabel('axe x')
plt.ylabel('axe y')
plt.title('exponentielle de x')
plt.plot(x,y)
# le traçage des tangente
for xi in range(1,11,2) :
    yi = np.exp(xi)
    plt.plot([xi-0.5,xi+0.5],[yi/2,yi+yi/2],'r')

# %% [markdown]
# #### logarithme

# %% [markdown]
# Explorez de la même façon la fonction logarithme. Jouez avec les valeurs de x. Est-ce un logarithme népérien ou en base 10?

# %% [markdown]
# - Réponse : C'est un logarithme népérien

# %%
# à vous
x = np.linspace(0,10,100)
x = np.delete(x,[0])
y = np.log(x)
plt.plot(x,y)
plt.xlabel('axe x')
plt.ylabel('axe y')
plt.title('logarithme de x')
# Out:
# Text(0.5, 1.0, 'logarithme de x')

# %% [markdown]
# Ajoutez les segments de pente 1/xi:

# %%
# à vous
x = np.linspace(0,10,100)
x = np.delete(x,[0])
y = np.log(x)
plt.plot(x,y)
plt.xlabel('axe x')
plt.ylabel('axe y')
plt.title('logarithme de x')
for xi in range (1,11,2) :
    z = np.linspace(xi-0.5,xi+0.5,10)
    yi = (1/xi)*(z-xi) + np.log(xi)
    plt.plot(z,yi,'r')

# %% [markdown]
# #### combiner log et exp

# %%
# tracer la fonction f(x) = log(exp(x))
x = np.linspace(0,10,100)
y = np.log(np.exp(x))
plt.plot(x,y)
plt.xlabel('axe x')
plt.ylabel('axe y')
plt.title('logarithme de exp de x')
# Out:
# Text(0.5, 1.0, 'logarithme de exp de x')

# %% [markdown]
# #### sinusoïde

# %% [markdown]
# Mêmes questions.

# %%
# à vous
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y)
plt.xlabel('axe x')
plt.ylabel('axe y')
plt.title('sin de x')
# Out:
# Text(0.5, 1.0, 'sin de x')

# %%
# avec les segments de pente ...
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y)
plt.xlabel('axe x')
plt.ylabel('axe y')
plt.title('sin de x')
for xi in range (1,11,2) :
    z = np.linspace(xi-0.5,xi+0.5,10)
    yi = np.cos(xi)*(z-xi) + np.sin(xi)
    plt.plot(z,yi,'r')

# %% [markdown]
# ### 1.2 Dessiner des points

# %% [markdown]
# Dessinez 200 points aléatoires (loi uniforme: np.random.uniform). Testez différentes [couleurs](https://matplotlib.org/stable/gallery/color/named_colors.html) et différents [markers](https://matplotlib.org/stable/api/markers_api.html).

# %%
# à vous
x = np.arange(0,200)
a = np.random.uniform(-2,2,200)
plt.scatter(x,a, marker="x", color='r')

# %% [markdown]
# Faites de même mais avec une loi gaussienne (np.random.normal).

# %%
# à vous
x = np.arange(0,200)
a = np.random.normal(-2,2,200)
plt.scatter(x,a, marker="x", color='r')

# %% [markdown]
# ## 2. Chronogrammes
# ### 2.1 Sons générés

# %%
# %pip install librosa==0.8.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: librosa==0.8.1 in /home/tsukoyachi/.local/lib/python3.10/site-packages (0.8.1)
# Requirement already satisfied: numpy>=1.15.0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from librosa==0.8.1) (1.23.5)
# Requirement already satisfied: audioread>=2.0.0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from librosa==0.8.1) (3.0.0)
# Requirement already satisfied: scipy>=1.0.0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from librosa==0.8.1) (1.10.0)
# Requirement already satisfied: pooch>=1.0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from librosa==0.8.1) (1.6.0)
# Requirement already satisfied: resampy>=0.2.2 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from librosa==0.8.1) (0.4.2)
# Requirement already satisfied: numba>=0.43.0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from librosa==0.8.1) (0.56.4)
# Requirement already satisfied: packaging>=20.0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from librosa==0.8.1) (23.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from librosa==0.8.1) (1.2.1)
# Requirement already satisfied: soundfile>=0.10.2 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from librosa==0.8.1) (0.12.1)
# Requirement already satisfied: decorator>=3.0.0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from librosa==0.8.1) (5.1.1)
# Requirement already satisfied: joblib>=0.14 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from librosa==0.8.1) (1.2.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from numba>=0.43.0->librosa==0.8.1) (59.6.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from numba>=0.43.0->librosa==0.8.1) (0.39.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/lib/python3/dist-packages (from pooch>=1.0->librosa==0.8.1) (2.25.1)
# Requirement already satisfied: appdirs>=1.3.0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from pooch>=1.0->librosa==0.8.1) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa==0.8.1) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /home/tsukoyachi/.local/lib/python3.10/site-packages (from soundfile>=0.10.2->librosa==0.8.1) (1.15.1)
# Requirement already satisfied: pycparser in /home/tsukoyachi/.local/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.8.1) (2.21)
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#chargement des librairies
import librosa
import librosa.display
import IPython.display as ipd

# %% [markdown]
# Pour un premier son, générez un 'la' de référence 440Hz.

# %%
#un petit test de son
n=6400# nombre d'échantillons
te=1/8000.0 # période d'échantillonnage
fe=8000 # fréquence d'échantillonnage
t = np.linspace(0, n*te, n,endpoint=False)
# accordons-nous sur un la 440 Hz
s= np.cos(2*np.pi*440*t)

# %% [markdown]
# Combien de temps dure ce son?

# %% [markdown]
# - Réponse : Le son dure te*n = 0.8s

# %%
# écoutons 
ipd.Audio(s,rate=fe,autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Testez d'autres fréquences et d'autres combinaison de sinusoïdes. Par exemple la somme d'un son pur à 440 Hz et d'un autre à 200 Hz de puissance double.

# %%
s = 0.25*np.cos(2*np.pi*440*t+0.5) + 0.5*np.cos(2*np.pi*200*t)

# %% [markdown]
# Comment faire durer le son plus longtemps? Par exemple 4 secondes.

# %% [markdown]
# - Réponse : Pour augmenter le temps, soit on ajoute des échantillons avec n soit on augmente la période d'échantillonage. Dans notre cas, multiplier n par 5 nous fera passer de 0,8 à 4 secondes.

# %% [markdown]
# Modifiez la fréquence d'échantillonage mais juste pour l'écoute. Qu'observez-vous?

# %% [markdown]
#  - Réponse : Cela dégrade la qualité du son et le rend plus sourd

# %%
ipd.Audio(s,rate=0.8*fe,autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(s,rate=1.2*fe,autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# regardons
# 2 types de visualisation: par librosa.display.waveplot et par plt.plot
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(20, 5))
librosa.display.waveplot(s,sr=fe, ax=ax1)
ax2.set_xlabel('temps (s)')
ax2.set_ylabel('amplitude')
ax2.set_title("chronogramme")
ax2.plot(t,s)
plt.title("chronogramme")
plt.show()

# %% [markdown]
# Voyez-vous les belles sinusoïdes? Pourquoi? Comment modifier la visualisation?

# %% [markdown]
# - Réponse : Il fallait juste baisser le nombre d'échantillons, ici on l'a passé à 100 pour avoir un résultat correct.

# %%
# Recalcul de la courbe pour avoir un truc plus propre avec seulement 100 échantillons
n=200# nombre d'échantillons
t = np.linspace(0, n*te, n,endpoint=False)
s = 0.25*np.cos(2*np.pi*440*t+0.5) + 0.5*np.cos(2*np.pi*200*t)
# 2 types de visualisation: par librosa.display.waveplot et par plt.plot
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(20, 5))
librosa.display.waveplot(s,sr=fe, ax=ax1)
ax2.set_xlabel('temps (s)')
ax2.set_ylabel('amplitude')
ax2.set_title("chronogramme")
ax2.plot(t,s)
plt.title("chronogramme")
plt.show()

# %% [markdown]
# ### 2.2 Sons réels

# %% [markdown]
# Il est possible de charger des sons que vous possédez sur votre disque dur ou bien en provenance de la librairie librosa.

# %%
#son sur mon disque dur, issu de https://philharmonia.co.uk/resources/sound-samples/
y1, sr1 = librosa.load('cello_G2_1_forte_arco-normal.mp3')
#son issu de librosa
y2, sr2 = librosa.load(librosa.ex('choice'), duration=10)

# %% [markdown]
# ## 3. Quantification et échantillonnage

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(20, 5))
n=200
#prendre 1 échantillon sur 2
t = np.linspace(0, n*te, n,endpoint=False)
t = t[::2]
s = 0.25*np.cos(2*np.pi*440*t+0.5) + 0.5*np.cos(2*np.pi*200*t)
# écouter et dessiner
ipd.Audio(s,rate=fe,autoplay=True)

ax1.plot(t,s)
ax1.set_xlabel('axe x')
ax1.set_ylabel('axe y')
ax1.set_title('1 échantillon sur 2')

#essayer d'autres sous-echantillonnage (1 sur 4, 1 sur 8 ....)
t = np.linspace(0, n*te, n,endpoint=False)
t = t[::4]
s2 = 0.25*np.cos(2*np.pi*440*t+0.5) + 0.5*np.cos(2*np.pi*200*t)
# écouter et dessiner

ax2.plot(t,s2)
ax2.set_xlabel('axe x')
ax2.set_ylabel('axe y')
ax2.set_title('1 échantillon sur 4')
# Out:
# Text(0.5, 1.0, '1 échantillon sur 4')

# %%
#Ecoutons les sons dessinés juste avant :
#1 echantillon sur 2
ipd.Audio(s,rate=fe,autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#1 echantillon sur 4
ipd.Audio(s2,rate=fe,autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#quantifier les valeurs sur un nombre de bits défini: q

# %%
# si vous avez encore des oreilles en état, vous pouvez également jouer sur la quantification
## sur b bits
t = np.linspace(0, n*te, n,endpoint=False)
t = t[::2]
b = 4 # à vous de modifier avec cette valeur
Q = 2**(1-b)
s = Q*np.floor(s/Q)
plt.plot(t,s)

# %% [markdown]
# # TD2
#
# ### Partie 1 : Choisir un son et afficher son chronogramme, son spectre et son spectrogramme puis refaire la même chose avec les autres sons
#
# ### Partie 2 : calculer les MFCCs de differents sont et les afficher

# %%
# Partie 1, son bird.wav
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(20, 5))
#Chronogramme
s,fe=librosa.load('bird.wav')
n = len(s)
t = np.linspace(0, n/fe, n,endpoint=False)
ax1.set_xlabel('seconds')
ax1.set_title('chronogramme du son bird.wav')
ax1.plot(t,s)

#Spectre
S=np.abs(np.fft.rfft(s))
tf=np.fft.rfftfreq(len(s),1/fe)
ax2.set_xlabel('seconds')
ax2.set_title('spectre du son bird.wav')
ax2.plot(tf,S)

# %%
#Spectrogramme du son bird.wav
S = np.abs(librosa.stft(s))
Sdb = librosa.amplitude_to_db(abs(S))
librosa.display.specshow(Sdb, sr=fe, x_axis='s', y_axis='hz')

# %%
# Partie 1, son dog.wav
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(20, 5))
#Chronogramme
s,fe=librosa.load('dog.wav')
n = len(s)
t = np.linspace(0, n/fe, n,endpoint=False)
ax1.set_xlabel('seconds')
ax1.set_title('chronogramme du son dog.wav')
ax1.plot(t,s)

#Spectre
S=np.abs(np.fft.rfft(s))
tf=np.fft.rfftfreq(len(s),1/fe)
ax2.set_xlabel('seconds')
ax2.set_title('spectre du son dog.wav')
ax2.plot(tf,S)

# %%
#Spectrogramme du son dog.wav
S = np.abs(librosa.stft(s))
Sdb = librosa.amplitude_to_db(abs(S))
librosa.display.specshow(Sdb, sr=fe, x_axis='s', y_axis='hz')

# %%
# Partie 1, son cat.wav
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(20, 5))
#Chronogramme
s,fe=librosa.load('cat.wav')
n = len(s)
t = np.linspace(0, n/fe, n,endpoint=False)
ax1.set_xlabel('seconds')
ax1.set_title('chronogramme du son cat.wav')
ax1.plot(t,s)

#Spectre
S=np.abs(np.fft.rfft(s))
tf=np.fft.rfftfreq(len(s),1/fe)
ax2.set_xlabel('seconds')
ax2.set_title('spectre du son cat.wav')
ax2.plot(tf,S)

# %%
#Spectrogramme du son cat.wav
S = np.abs(librosa.stft(s))
Sdb = librosa.amplitude_to_db(abs(S))
librosa.display.specshow(Sdb, sr=fe, x_axis='s', y_axis='hz')
